# %% [markdown]
# ### Install the required library

# %%
# !pip3 install qai-hub
# Out:
# Collecting qai-hub
#   Downloading qai_hub-0.27.0-py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.2 kB ? eta -:--:--
#      ---------------------------------------- 102.2/102.2 kB ? eta 0:00:00
# Collecting prettytable>=3.9.0
#   Downloading prettytable-3.16.0-py3-none-any.whl (33 kB)
# Collecting backoff>=2.2
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting numpy<2,>=1.22.0
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      - -------------------------------------- 0.5/15.8 MB 15.9 MB/s eta 0:00:01
#      -- ------------------------------------- 1.0/15.8 MB 12.9 MB/s eta 0:00:02
#      ---- ----------------------------------- 1.8/15.8 MB 16.4 MB/s eta 0:00:01
#      ------- -------------------------------- 2.9/15.8 MB 18.3 MB/s eta 0:00:01
#      --------- ------------------------------ 3.9/15.8 MB 17.9 MB/s eta 0:00:01
#      ----------- ---------------------------- 4.7/15.8 MB 17.8 MB/s eta 0:00:01
#      -------------- ------------------------- 5.9/15.8 MB 17.9 MB/s eta 0:00:01
#      ------------------ --------------------- 7.2/15.8 MB 19.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 8.9/15.8 MB 21.1 MB/s eta 0:00:01
#      -------------------------- ------------ 10.6/15.8 MB 23.4 MB/s eta 0:00:01
#      ----------------------------- --------- 11.8/15.8 MB 25.2 MB/s eta 0:00:01
#      --------------------------------- ----- 13.6/15.8 MB 28.4 MB/s eta 0:00:01
#      ------------------------------------ -- 14.9/15.8 MB 29.7 MB/s eta 0:00:01
#      --------------------------------------  15.8/15.8 MB 32.7 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 28.4 MB/s eta 0:00:00
# Collecting protobuf<4,>=3.20
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#      ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#      ------------------------------------- 904.0/904.0 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub) (24.2)
# Collecting semver>=3.0
#   Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting h5py<4,>=2.10.0
#   Downloading h5py-3.13.0-cp310-cp310-win_amd64.whl (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      --------------- ------------------------ 1.2/3.0 MB 37.0 MB/s eta 0:00:01
#      ------------------------------------- -- 2.7/3.0 MB 34.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub) (4.13.2)
# Collecting requests-toolbelt
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Collecting s3transfer<0.11,>=0.10.3
#   Downloading s3transfer-0.10.4-py3-none-any.whl (83 kB)
#      ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#      ---------------------------------------- 83.2/83.2 kB ? eta 0:00:00
# Collecting deprecation
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: wcwidth in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from prettytable>=3.9.0->qai-hub) (0.2.13)
# Collecting botocore<2.0a.0,>=1.33.2
#   Downloading botocore-1.37.33-py3-none-any.whl (13.5 MB)
#      ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#      ---- ----------------------------------- 1.4/13.5 MB 29.8 MB/s eta 0:00:01
#      --------- ------------------------------ 3.2/13.5 MB 33.9 MB/s eta 0:00:01
#      ------------- -------------------------- 4.6/13.5 MB 32.7 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.8/13.5 MB 30.6 MB/s eta 0:00:01
#      --------------------- ------------------ 7.2/13.5 MB 30.8 MB/s eta 0:00:01
#      -------------------------- ------------- 8.9/13.5 MB 31.7 MB/s eta 0:00:01
#      ------------------------------ -------- 10.6/13.5 MB 32.8 MB/s eta 0:00:01
#      ----------------------------------- --- 12.3/13.5 MB 32.8 MB/s eta 0:00:01
#      --------------------------------------  13.5/13.5 MB 34.4 MB/s eta 0:00:01
#      --------------------------------------- 13.5/13.5 MB 29.8 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-cp310-cp310-win_amd64.whl (102 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      ---------------------------------------- 0.0/128.7 kB ? eta -:--:--
#      -------------------------------------- 128.7/128.7 kB 7.9 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Requirement already satisfied: colorama in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from tqdm->qai-hub) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from botocore<2.0a.0,>=1.33.2->s3transfer<0.11,>=0.10.3->qai-hub) (2.9.0.post0)
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: six>=1.5 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0a.0,>=1.33.2->s3transfer<0.11,>=0.10.3->qai-hub) (1.17.0)
# Installing collected packages: urllib3, tqdm, semver, protobuf, prettytable, numpy, jmespath, idna, deprecation, charset-normalizer, certifi, backoff, requests, h5py, botocore, s3transfer, requests-toolbelt, qai-hub
# Successfully installed backoff-2.2.1 botocore-1.37.33 certifi-2025.1.31 charset-normalizer-3.4.1 deprecation-2.1.0 h5py-3.13.0 idna-3.10 jmespath-1.0.1 numpy-1.26.4 prettytable-3.16.0 protobuf-3.20.3 qai-hub-0.27.0 requests-2.32.3 requests-toolbelt-1.0.0 s3transfer-0.10.4 semver-3.0.4 tqdm-4.67.1 urllib3-2.4.0
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Put the API token from the online dashboard

# %%
# !qai-hub configure --api_token TOKEN
# Out:
# qai-hub configuration saved to C:\Users\m/.qai_hub/client.ini
# ==================== C:\Users\m/.qai_hub/client.ini ====================
# [api]
# api_token = TOKEN
# api_url = https://app.aihub.qualcomm.com
# web_url = https://app.aihub.qualcomm.com
# verbose = True
# C:\Users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\qai_hub\_cli.py:379: UserWarning: Overwriting configuration: C:\Users\m/.qai_hub/client.ini (previous configuration saved to C:\Users\m/.qai_hub/client.ini.bak)
#   warnings.warn(

# %%
# !pip3 install "qai-hub[torch]"
# Out:
# Requirement already satisfied: qai-hub[torch] in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (0.27.0)
# Requirement already satisfied: deprecation in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (2.1.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (4.13.2)
# Requirement already satisfied: tqdm in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (4.67.1)
# Requirement already satisfied: backoff>=2.2 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (2.2.1)
# Requirement already satisfied: prettytable>=3.9.0 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (3.16.0)
# Requirement already satisfied: protobuf<4,>=3.20 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (3.20.3)
# Requirement already satisfied: numpy<2,>=1.22.0 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (1.26.4)
# Requirement already satisfied: requests in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (2.32.3)
# Requirement already satisfied: requests-toolbelt in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (1.0.0)
# Requirement already satisfied: h5py<4,>=2.10.0 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (3.13.0)
# Requirement already satisfied: s3transfer<0.11,>=0.10.3 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (0.10.4)
# Requirement already satisfied: semver>=3.0 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (3.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from qai-hub[torch]) (24.2)
# Collecting torch>=1.13
#   Downloading torch-2.6.0-cp310-cp310-win_amd64.whl (204.2 MB)
#      ---------------------------------------- 0.0/204.2 MB ? eta -:--:--
#      --------------------------------------- 0.3/204.2 MB 18.6 MB/s eta 0:00:11
#      --------------------------------------- 0.9/204.2 MB 14.1 MB/s eta 0:00:15
#      --------------------------------------- 1.7/204.2 MB 13.7 MB/s eta 0:00:15
#      --------------------------------------- 2.5/204.2 MB 14.5 MB/s eta 0:00:14
#       -------------------------------------- 3.2/204.2 MB 15.7 MB/s eta 0:00:13
#       -------------------------------------- 4.1/204.2 MB 17.6 MB/s eta 0:00:12
#       -------------------------------------- 4.9/204.2 MB 18.5 MB/s eta 0:00:11
#      - ------------------------------------- 5.3/204.2 MB 17.8 MB/s eta 0:00:12
#      - ------------------------------------- 6.2/204.2 MB 18.0 MB/s eta 0:00:11
#      ------------------------------- ----- 174.1/204.2 MB 38.6 MB/s eta 0:00:01
#      ------------------------------- ----- 176.1/204.2 MB 40.9 MB/s eta 0:00:01
#      -------------------------------- ---- 178.4/204.2 MB 43.7 MB/s eta 0:00:01
#      -------------------------------- ---- 180.4/204.2 MB 40.9 MB/s eta 0:00:01
#      --------------------------------- --- 182.5/204.2 MB 46.7 MB/s eta 0:00:01
#      --------------------------------- --- 184.0/204.2 MB 43.5 MB/s eta 0:00:01
#      --------------------------------- --- 186.1/204.2 MB 43.5 MB/s eta 0:00:01
#      --------------------------------- --- 187.3/204.2 MB 40.9 MB/s eta 0:00:01
#      ---------------------------------- -- 189.3/204.2 MB 43.5 MB/s eta 0:00:01
#      ---------------------------------- -- 191.4/204.2 MB 43.5 MB/s eta 0:00:01
#      ---------------------------------- -- 192.9/204.2 MB 40.9 MB/s eta 0:00:01
#      ----------------------------------- - 195.1/204.2 MB 43.7 MB/s eta 0:00:01
#      ----------------------------------- - 196.7/204.2 MB 46.7 MB/s eta 0:00:01
#      ----------------------------------- - 198.4/204.2 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  200.4/204.2 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  202.1/204.2 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  204.2/204.2 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------- 204.2/204.2 MB 10.2 MB/s eta 0:00:00
# Collecting torchvision>=0.14
#   Downloading torchvision-0.21.0-cp310-cp310-win_amd64.whl (1.6 MB)
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#      ------------------------------------- -- 1.5/1.6 MB 30.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.6/1.6 MB 33.0 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from prettytable>=3.9.0->qai-hub[torch]) (0.2.13)
# Requirement already satisfied: botocore<2.0a.0,>=1.33.2 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from s3transfer<0.11,>=0.10.3->qai-hub[torch]) (1.37.33)
# Collecting fsspec
#   Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
#      ---------------------------------------- 0.0/194.4 kB ? eta -:--:--
#      ---------------------------------------- 194.4/194.4 kB ? eta 0:00:00
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting sympy==1.13.1
#   Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Collecting filelock
#   Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#      --------------- ------------------------ 1.0/2.7 MB 32.3 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 MB 33.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.7/2.7 MB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from requests->qai-hub[torch]) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from requests->qai-hub[torch]) (2025.1.31)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from requests->qai-hub[torch]) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from requests->qai-hub[torch]) (3.10)
# Requirement already satisfied: colorama in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from tqdm->qai-hub[torch]) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from botocore<2.0a.0,>=1.33.2->s3transfer<0.11,>=0.10.3->qai-hub[torch]) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from botocore<2.0a.0,>=1.33.2->s3transfer<0.11,>=0.10.3->qai-hub[torch]) (1.0.1)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Requirement already satisfied: six>=1.5 in c:\users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0a.0,>=1.33.2->s3transfer<0.11,>=0.10.3->qai-hub[torch]) (1.17.0)
# Installing collected packages: mpmath, sympy, pillow, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
# Successfully installed MarkupSafe-3.0.2 filelock-3.18.0 fsspec-2025.3.2 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 pillow-11.2.1 sympy-1.13.1 torch-2.6.0 torchvision-0.21.0
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Run below the mobilenet v2 model which is optimized for Snapdragon X Elite CRD. You can change the model type and device to your liking. After the job is triggered after executing below, you can see the details about the execution on the Qualcomm dashboard which also shows the model architecture diagram (quite cool!)

# %%
import qai_hub as hub
import torch
from torchvision.models import mobilenet_v2
import requests
import numpy as np
from PIL import Image

# Using pre-trained MobileNet
torch_model = mobilenet_v2(pretrained=True)
torch_model.eval()

# Step 1: Trace model
input_shape = (1, 3, 224, 224)
example_input = torch.rand(input_shape)
traced_torch_model = torch.jit.trace(torch_model, example_input)

# Step 2: Compile model
compile_job = hub.submit_compile_job(
    model=traced_torch_model,
    device=hub.Device("Snapdragon X Elite CRD"),
    input_specs=dict(image=input_shape),
    options="--target_runtime onnx",
)

# Step 3: Profile on cloud-hosted device
target_model = compile_job.get_target_model()
profile_job = hub.submit_profile_job(
    model=target_model,
    device=hub.Device("Snapdragon X Elite CRD"),
)

# Step 4: Run inference on cloud-hosted device
sample_image_url = (
    "https://qaihub-public-assets.s3.us-west-2.amazonaws.com/apidoc/input_image1.jpg"
)
response = requests.get(sample_image_url, stream=True)
response.raw.decode_content = True
image = Image.open(response.raw).resize((224, 224))
input_array = np.expand_dims(
    np.transpose(np.array(image, dtype=np.float32) / 255.0, (2, 0, 1)), axis=0
)

# Run inference using the on-device model on the input image
inference_job = hub.submit_inference_job(
    model=target_model,
    device=hub.Device("Snapdragon X Elite CRD"),
    inputs=dict(image=[input_array]),
)
on_device_output = inference_job.download_output_data()

# Step 5: Post-processing the on-device output
output_name = list(on_device_output.keys())[0]
out = on_device_output[output_name][0]
on_device_probabilities = np.exp(out) / np.sum(np.exp(out), axis=1)

# Read the class labels for imagenet
sample_classes = "https://qaihub-public-assets.s3.us-west-2.amazonaws.com/apidoc/imagenet_classes.txt"
response = requests.get(sample_classes, stream=True)
response.raw.decode_content = True
categories = [str(s.strip()) for s in response.raw]

# Print top five predictions for the on-device model
print("Top-5 On-Device predictions:")
top5_classes = np.argsort(on_device_probabilities[0], axis=0)[-5:]
for c in reversed(top5_classes):
    print(f"{c} {categories[c]:20s} {on_device_probabilities[0][c]:>6.1%}")

# Step 6: Download model
target_model = compile_job.get_target_model()
target_model.download("mobilenet_v2.onnx")
# Out:
# c:\Users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\m\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to C:\Users\m/.cache\torch\hub\checkpoints\mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 31.7MB/s]
# Uploading tmp5og0lqd5.pt
# 100%|██████████| 13.9M/13.9M [00:02<00:00, 5.43MB/s]
# Scheduled compile job (j56ee436g) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/j56ee436g/
#
# Waiting for compile job (j56ee436g) completion. Type Ctrl+C to stop waiting at any time.
#     ✅ SUCCESS
# Scheduled profile job (jp3vv043g) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jp3vv043g/
# Uploading dataset: 154kB [00:00, 670kB/s]                    <?, ?B/s]
# Scheduled inference job (jgokk61qp) successfully. To see the status and results:
#     https://app.aihub.qualcomm.com/jobs/jgokk61qp/
#
# Waiting for inference job (jgokk61qp) completion. Type Ctrl+C to stop waiting at any time.
#     ✅ SUCCESS
# tmp_m09pwup.h5: 100%|██████████| 14.5k/14.5k [00:00<?, ?B/s]
# Top-5 On-Device predictions:
# 968 b'cup'                71.3%
# 504 b'coffee mug'         16.4%
# 967 b'espresso'            7.8%
# 809 b'soup bowl'           1.4%
# 659 b'mixing bowl'         1.3%
# mobilenet_v2.onnx: 100%|██████████| 13.3M/13.3M [00:01<00:00, 10.8MB/s]
# Downloaded model to mobilenet_v2.onnx
# 'mobilenet_v2.onnx'
